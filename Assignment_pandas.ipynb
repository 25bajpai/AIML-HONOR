# %%
# %pip install pandas

# %%
import pandas as pd

columns = ['emp_id' , 'name','department', 'salary']

df = pd.DataFrame(columns= columns)

df.to_csv('database.csv',index = False)

# %%
print('Enter your choice : ')
print('1. Create ;')
print('2. Update ;')
print('3. Read ;')
print('4. Delete ;')
ip = int(input())
# Out:
# Enter your choice :
# 1. Create ;
# 2. Update ;
# 3. Read ;
# 4. Delete ;
# 3

# %%
if (ip == 1):
  id = input("Enter id :")
  name = input("Enter Name :")
  department = input("Enter Department :")
  salary = input("Enter salary :")
  init_data = pd.DataFrame([{'id':id,'name':name,'department':department,'salary':salary}])
  df = pd.concat([df, init_data], ignore_index=True)
  df.to_csv('database.csv', index=False)
  print('Data added successfully;')

elif(ip == 2):
  # up_id = input("Enter emp_id to update : ")
  # up_data = input("Enter the data to update : ")+"\n"

  # new_record = pd.DataFrame([{'user_id': 103, 'username': 'charlie_dev', 'signup_date': '2026-09-25'}])
  # df = pd.concat([df, new_record], ignore_index=True)
  # df.to_csv('database.csv', index=False)
  # print('Data updated successfully;')

elif(ip == 3):
  df = pd.read_csv('database.csv')
  print('-x-\n')

elif(ip == 4):
  del_id = input("Enter emp_id to delete : ")
  df = df[df['id' != del_id]]
  df.to_csv('database.csv', index=False)
  print('Deleted Sucessfully')

else :
  print("Invalid Operation!!!")
# Out:
# -x-
